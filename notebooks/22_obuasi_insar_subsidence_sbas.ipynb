# %% [markdown]
# # Obuasi Mining Subsidence — Full InSAR Chain, Search to SBAS
#
# **A complete, real InSAR project: Search  → Download → SLC extraction → interferogram
# formation → atmospheric correction → phase unwrapping → SBAS time
# series inversion.** No synthetic data anywhere. Every processing step
# uses PyGeoFetch's real InSAR pipeline, with `DataValidator` wired in
# automatically at each entry point and automatic visualization at every
# stage — no separate manual plotting step required.
#
# ## CPU-only, explicitly and by design
#
# **This notebook runs entirely on CPU.** Every processing call below
# sets `use_gpu=False` explicitly, even though it's already the library
# default — not left implicit, so this is unambiguous. This is a
# deliberate choice, not a limitation worked around: the CPU path is the
# one that's been directly, exhaustively tested this session (byte-for-byte
# regression-verified against the pre-existing implementation). The
# optional GPU path exists in the library for large scenes, but hasn't
# been verified against real GPU hardware — if you don't have a GPU, or
# simply want the path that's been fully verified, this notebook is
# exactly that path. Nothing here requires a GPU to run correctly.
#
# ## Why Obuasi, and why InSAR specifically
#
# This connects directly to the earlier Obuasi vegetation-decline
# analysis in this project series (real Landsat NDVI trend showing
# measurable decline 2018–2023 across the mining belt). Optical data can
# show *that* vegetation is declining; it can't show *why* — surface
# subsidence from underground mining activity is a real, physically
# distinct signal that InSAR is specifically suited to detect, and that
# optical imagery cannot see at all. Together, a real, multi-sensor
# picture: vegetation loss *and* ground deformation, not just one or the
# other.
#
# ## Study area
#
# Obuasi, Ashanti Region — home to one of Ghana's largest gold mining
# operations (AngloGold Ashanti), with both underground and historical
# surface mining activity. Real, well-known town coordinates
# (6.2027°N, 1.6708°W) anchor the AOI.

# %%
from pathlib import Path
import numpy as np

from pygeofetch import PyGeoFetch
from pygeofetch.models.search_query import SearchQuery, BoundingBox
from pygeofetch.models.download_task import DownloadOptions
from pygeofetch.insar import (
    SLCExtractor, InterferogramGenerator, AtmosphericCorrector,
    PhaseUnwrapper, SBASTimeSeries, DataValidator, gpu_available,
)
from pygeofetch.insar.timeseries import InterferogramPair
from pygeofetch.insar.visualize import visualize_interferogram, visualize_unwrapped, visualize_timeseries
from pygeofetch.viz import Plotter, MapViewer

pl = Plotter(figsize=(12, 9))
print("Modules loaded")
print(f"GPU available in this environment: {gpu_available()} -- this notebook runs on CPU regardless (use_gpu=False set explicitly throughout)")
# Out:
# Modules loaded
# GPU available in this environment: False -- this notebook runs on CPU regardless (use_gpu=False set explicitly throughout)

# %% [markdown]
# ## 1. Study Area — Obuasi mining belt

# %%
obuasi_center = (-1.6708, 6.2027)  # lon, lat -- real, well-known town coordinates

import json

obuasi_boundary_coords = [
    [-1.7427, 6.2277], [-1.7210, 6.2381], [-1.6946, 6.2413],
    [-1.6665, 6.2341], [-1.6465, 6.2221], [-1.6328, 6.2036],
    [-1.6360, 6.1820], [-1.6545, 6.1635], [-1.6809, 6.1531],
    [-1.7082, 6.1555], [-1.7322, 6.1691], [-1.7467, 6.1900],
    [-1.7531, 6.2092], [-1.7427, 6.2277],
]
obuasi_geometry = {"type": "Polygon", "coordinates": [obuasi_boundary_coords]}

obuasi_lons = [c[0] for c in obuasi_boundary_coords]
obuasi_lats = [c[1] for c in obuasi_boundary_coords]
aoi_extent = (min(obuasi_lons), max(obuasi_lons), min(obuasi_lats), max(obuasi_lats))

output_dir = Path("./data/obuasi_insar")
output_dir.mkdir(parents=True, exist_ok=True)
print(f"Study area: Obuasi Municipal District, {len(obuasi_boundary_coords)-1} vertices")
print(f"Extent: {aoi_extent}")
# Out:
# Study area: Obuasi Municipal District, 13 vertices
# Extent: (-1.7531, -1.6328, 6.1531, 6.2413)

# %% [markdown]
# ## 2. Search — Sentinel-1 SLC (not GRD)
#
# InSAR specifically requires **SLC** (Single Look Complex) products —
# GRD products have already lost the phase information InSAR depends
# on entirely. Six dates across dry-season windows, for a real,
# multi-baseline SBAS network rather than a single pair.

# %%
client = PyGeoFetch(log_level="INFO")
COPERNICUS_USERNAME = "appiahkubis14@gmail.com"
COPERNICUS_PASSWORD = "CDSE@sak@19999eocoreint"
client.add_credentials("copernicus", username=COPERNICUS_USERNAME, password=COPERNICUS_PASSWORD)
# "copernicus", username="appiahkubis14@gmail.com", password="CDSE@sak@19999eocoreint"

# Same relative orbit/pass geometry is essential for real coregistration --
# narrow date windows spaced roughly one Sentinel-1 repeat cycle (12 days)
# apart, all targeting the same descending pass over this AOI
search_windows = [
    ("2024-11-01", "2024-11-08"), ("2024-11-13", "2024-11-20"),
    ("2024-11-25", "2024-12-02"), ("2024-12-07", "2024-12-14"),
    ("2024-12-19", "2024-12-26"), ("2025-01-01", "2025-01-08"),
]

scenes = {}
for start, end in search_windows:
    query = SearchQuery(
        geometry=obuasi_geometry, start_date=start, end_date=end,
        product_type="SLC", polarisation="VV", max_results=5,
    )
    results = client.search(query, providers=["copernicus"])
    if results:
        best = results[0]
        label = str(best.datetime.date()) if best.datetime else start
        scenes[label] = best
        print(f"  {start[:10]}: {best.id} ({label})")
    else:
        print(f"  {start[:10]}: no SLC scenes found")

if len(scenes) < 3:
    raise RuntimeError(
        f"Only {len(scenes)} SLC scene(s) found -- SBAS needs at least 3 "
        f"dates for a meaningful network. Widen the search windows and "
        f"try again. No synthetic fallback is used."
    )
print(f"\n{len(scenes)} dates found -- proceeding with real SLC data only.")
# Out:
# 17:33:31 INFO [      engine] PyGeoFetch ready
# 17:33:31 INFO [authenticator] Credentials saved for provider 'copernicus'
# ┌ SEARCH PARAMETERS ───────────────────────────────────────────────────────┐
# │ Providers  : copernicus                                                  │
# │ BBox       : —                                                           │
# │ Date range : 2024-11-01  →  2024-11-08                                   │
# │ Cloud max  : 100%                                                        │
# │ Product    : SLC                                                         │
# └──────────────────────────────────────────────────────────────────────────┘
# 17:33:33 INFO [  copernicus] Authenticated with Copernicus Data Space as 'appiahkubis14@gmail.com'
#   ✓  copernicus                       2 scenes   3.2s
# ┌────────────────────────────────────────────┬────────────┬────────────────┬────────┬─────────┬──────────────┬─────────────┬───────┬───────┬──────────────────────┐
# │                  SCENE ID                  │    DATE    │   SATELLITE    │ CLOUD  │ PRODUCT │ POLARISATION │    PASS     │ ORBIT │ SCORE │       PROVIDER       │
# ├────────────────────────────────────────────┼────────────┼────────────────┼────────┼─────────┼──────────────┼─────────────┼───────┼───────┼──────────────────────┤
# │ 653cc68d-6b97-411d-9239-f6880ecd7449       │ 2024-11-08 │ SENTINEL-1A    │ —      │ IW_SLC… │ VV&VH        │ ascending   │ 45    │ 0.50  │ copernicus           │
# │ 7d113ef7-9055-4f1b-bfe7-c664437008cd       │ 2024-11-03 │ SENTINEL-1A    │ —      │ IW_SLC… │ VV&VH        │ ascending   │ 147   │ 0.50  │ copernicus           │
# └────────────────────────────────────────────┴────────────┴────────────────┴────────┴─────────┴──────────────┴─────────────┴───────┴───────┴──────────────────────┘
#   2 scenes found  ·  3.2s
#   2024-11-01: 653cc68d-6b97-411d-9239-f6880ecd7449 (2024-11-08)
# ┌ SEARCH PARAMETERS ───────────────────────────────────────────────────────┐
# │ Providers  : copernicus                                                  │
# │ BBox       : —                                                           │
# │ Date range : 2024-11-13  →  2024-11-20                                   │
# │ Cloud max  : 100%                                                        │
# │ Product    : SLC                                                         │
# └──────────────────────────────────────────────────────────────────────────┘
#   ✓  copernicus                       2 scenes   1.6s
# ┌────────────────────────────────────────────┬────────────┬────────────────┬────────┬─────────┬──────────────┬─────────────┬───────┬───────┬──────────────────────┐
# │                  SCENE ID                  │    DATE    │   SATELLITE    │ CLOUD  │ PRODUCT │ POLARISATION │    PASS     │ ORBIT │ SCORE │       PROVIDER       │
# ├────────────────────────────────────────────┼────────────┼────────────────┼────────┼─────────┼──────────────┼─────────────┼───────┼───────┼──────────────────────┤
# │ afec3b79-a9a8-456a-adfe-58ac22a4a7e2       │ 2024-11-20 │ SENTINEL-1A    │ —      │ IW_SLC… │ VV&VH        │ ascending   │ 45    │ 0.50  │ copernicus           │
# │ b6763563-aa42-4e70-aa1f-b0f288cbcd66       │ 2024-11-15 │ SENTINEL-1A    │ —      │ IW_SLC… │ VV&VH        │ ascending   │ 147   │ 0.50  │ copernicus           │
# └────────────────────────────────────────────┴────────────┴────────────────┴────────┴─────────┴──────────────┴─────────────┴───────┴───────┴──────────────────────┘
#   2 scenes found  ·  1.6s
#   2024-11-13: afec3b79-a9a8-456a-adfe-58ac22a4a7e2 (2024-11-20)
# ┌ SEARCH PARAMETERS ───────────────────────────────────────────────────────┐
# │ Providers  : copernicus                                                  │
# │ BBox       : —                                                           │
# │ Date range : 2024-11-25  →  2024-12-02                                   │
# │ Cloud max  : 100%                                                        │
# │ Product    : SLC                                                         │
# └──────────────────────────────────────────────────────────────────────────┘
#   ✓  copernicus                       2 scenes   1.4s
# ┌────────────────────────────────────────────┬────────────┬────────────────┬────────┬─────────┬──────────────┬─────────────┬───────┬───────┬──────────────────────┐
# │                  SCENE ID                  │    DATE    │   SATELLITE    │ CLOUD  │ PRODUCT │ POLARISATION │    PASS     │ ORBIT │ SCORE │       PROVIDER       │
# ├────────────────────────────────────────────┼────────────┼────────────────┼────────┼─────────┼──────────────┼─────────────┼───────┼───────┼──────────────────────┤
# │ da2f383e-bb92-4640-8483-d9178da6de41       │ 2024-12-02 │ SENTINEL-1A    │ —      │ IW_SLC… │ VV&VH        │ ascending   │ 45    │ 0.50  │ copernicus           │
# │ cb986065-89c9-43c1-b8b0-ab95f58c8cf4       │ 2024-11-27 │ SENTINEL-1A    │ —      │ IW_SLC… │ VV&VH        │ ascending   │ 147   │ 0.50  │ copernicus           │
# └────────────────────────────────────────────┴────────────┴────────────────┴────────┴─────────┴──────────────┴─────────────┴───────┴───────┴──────────────────────┘
#   2 scenes found  ·  1.4s
#   2024-11-25: da2f383e-bb92-4640-8483-d9178da6de41 (2024-12-02)
# ┌ SEARCH PARAMETERS ───────────────────────────────────────────────────────┐
# │ Providers  : copernicus                                                  │
# │ BBox       : —                                                           │
# │ Date range : 2024-12-07  →  2024-12-14                                   │
# │ Cloud max  : 100%                                                        │
# │ Product    : SLC                                                         │
# └──────────────────────────────────────────────────────────────────────────┘
#   ✓  copernicus                       2 scenes   2.4s
# ┌────────────────────────────────────────────┬────────────┬────────────────┬────────┬─────────┬──────────────┬─────────────┬───────┬───────┬──────────────────────┐
# │                  SCENE ID                  │    DATE    │   SATELLITE    │ CLOUD  │ PRODUCT │ POLARISATION │    PASS     │ ORBIT │ SCORE │       PROVIDER       │
# ├────────────────────────────────────────────┼────────────┼────────────────┼────────┼─────────┼──────────────┼─────────────┼───────┼───────┼──────────────────────┤
# │ 7210e023-cbad-4a47-a6bc-9c122d34cc13       │ 2024-12-14 │ SENTINEL-1A    │ —      │ IW_SLC… │ VV&VH        │ ascending   │ 45    │ 0.50  │ copernicus           │
# │ 839f097d-1d93-416e-9405-20690ad65f1b       │ 2024-12-09 │ SENTINEL-1A    │ —      │ IW_SLC… │ VV&VH        │ ascending   │ 147   │ 0.50  │ copernicus           │
# └────────────────────────────────────────────┴────────────┴────────────────┴────────┴─────────┴──────────────┴─────────────┴───────┴───────┴──────────────────────┘
#   2 scenes found  ·  2.4s
#   2024-12-07: 7210e023-cbad-4a47-a6bc-9c122d34cc13 (2024-12-14)
# ┌ SEARCH PARAMETERS ───────────────────────────────────────────────────────┐
# │ Providers  : copernicus                                                  │
# │ BBox       : —                                                           │
# │ Date range : 2024-12-19  →  2024-12-26                                   │
# │ Cloud max  : 100%                                                        │
# │ Product    : SLC                                                         │
# └──────────────────────────────────────────────────────────────────────────┘
#   ✓  copernicus                       2 scenes   1.1s
# ┌────────────────────────────────────────────┬────────────┬────────────────┬────────┬─────────┬──────────────┬─────────────┬───────┬───────┬──────────────────────┐
# │                  SCENE ID                  │    DATE    │   SATELLITE    │ CLOUD  │ PRODUCT │ POLARISATION │    PASS     │ ORBIT │ SCORE │       PROVIDER       │
# ├────────────────────────────────────────────┼────────────┼────────────────┼────────┼─────────┼──────────────┼─────────────┼───────┼───────┼──────────────────────┤
# │ e9a3c871-6bb4-4a0b-aa4f-844da0aab8d5       │ 2024-12-26 │ SENTINEL-1A    │ —      │ IW_SLC… │ VV&VH        │ ascending   │ 45    │ 0.50  │ copernicus           │
# │ 64a32d9f-e761-45a7-b2cc-c28843859457       │ 2024-12-21 │ SENTINEL-1A    │ —      │ IW_SLC… │ VV&VH        │ ascending   │ 147   │ 0.50  │ copernicus           │
# └────────────────────────────────────────────┴────────────┴────────────────┴────────┴─────────┴──────────────┴─────────────┴───────┴───────┴──────────────────────┘
#   2 scenes found  ·  1.1s
#   2024-12-19: e9a3c871-6bb4-4a0b-aa4f-844da0aab8d5 (2024-12-26)
# ┌ SEARCH PARAMETERS ───────────────────────────────────────────────────────┐
# │ Providers  : copernicus                                                  │
# │ BBox       : —                                                           │
# │ Date range : 2025-01-01  →  2025-01-08                                   │
# │ Cloud max  : 100%                                                        │
# │ Product    : SLC                                                         │
# └──────────────────────────────────────────────────────────────────────────┘
#   ✓  copernicus                       2 scenes   1.6s
# ┌────────────────────────────────────────────┬────────────┬────────────────┬────────┬─────────┬──────────────┬─────────────┬───────┬───────┬──────────────────────┐
# │                  SCENE ID                  │    DATE    │   SATELLITE    │ CLOUD  │ PRODUCT │ POLARISATION │    PASS     │ ORBIT │ SCORE │       PROVIDER       │
# ├────────────────────────────────────────────┼────────────┼────────────────┼────────┼─────────┼──────────────┼─────────────┼───────┼───────┼──────────────────────┤
# │ c6727038-f036-499c-a2ae-cf7911d7e121       │ 2025-01-07 │ SENTINEL-1A    │ —      │ IW_SLC… │ VV&VH        │ ascending   │ 45    │ 0.50  │ copernicus           │
# │ 53092b6d-08c7-4c9e-9408-dd7091f40662       │ 2025-01-02 │ SENTINEL-1A    │ —      │ IW_SLC… │ VV&VH        │ ascending   │ 147   │ 0.50  │ copernicus           │
# └────────────────────────────────────────────┴────────────┴────────────────┴────────┴─────────┴──────────────┴─────────────┴───────┴───────┴──────────────────────┘
#   2 scenes found  ·  1.6s
#   2025-01-01: c6727038-f036-499c-a2ae-cf7911d7e121 (2025-01-07)
#
# 6 dates found -- proceeding with real SLC data only.

# %%
import httpx

for label, scene in scenes.items():
    url = f"https://catalogue.dataspace.copernicus.eu/odata/v1/Products({scene.id})?$select=Footprint"
    resp = httpx.get(url, timeout=30)
    footprint = resp.json().get("Footprint", "")
    print(f"{label}: {footprint[:80]}...")
# Out:
# 2024-11-08: geography'SRID=4326;POLYGON ((-3.540103 4.290281, -1.312811 4.754363, -1.678733 ...
# 2024-11-20: geography'SRID=4326;POLYGON ((-3.540614 4.290725, -1.313332 4.754767, -1.679181 ...
# 2024-12-02: geography'SRID=4326;POLYGON ((-3.540657 4.29039, -1.313387 4.754374, -1.679221 6...
# 2024-12-14: geography'SRID=4326;POLYGON ((-3.540981 4.290127, -1.313586 4.754121, -1.679433 ...
# 2024-12-26: geography'SRID=4326;POLYGON ((-3.540241 4.290459, -1.31284 4.754488, -1.678613 6...
# 2025-01-07: geography'SRID=4326;POLYGON ((-3.540308 4.290487, -1.312949 4.75454, -1.678797 6...

# %% [markdown]
# ## 3. Download

# %%
download_options = DownloadOptions(parallel=1, resume=True, on_failure="skip")
download_results = {}

for label, scene in scenes.items():
    scene_dir = output_dir / "raw" / label
    result = client.download([scene], destination=scene_dir, options=download_options)[0]
    print(f"  {label}: {'OK' if result.success else f'FAILED: {result.error}'}")
    if result.success:
        download_results[label] = result

if len(download_results) < 3:
    raise RuntimeError(f"Only {len(download_results)} download(s) succeeded -- need at least 3.")
# Out:
# ⬇ 1 scene  →  data/obuasi_insar/raw/2024-11-08              0/1  [00:00]
# 653cc68d-6b97-411d-9239-f6880ecd7449: 0.00B [00:00, ?B/s]
# 17:34:00 INFO [  downloader]   ↷ 653cc68d-6b97-411d-9239-f6880ecd7449          already downloaded, skipping (resume=True)
#   2024-11-08: OK
# ⬇ 1 scene  →  data/obuasi_insar/raw/2024-11-20              0/1  [00:00]
# afec3b79-a9a8-456a-adfe-58ac22a4a7e2: 0.00B [00:00, ?B/s]
# 17:34:14 INFO [  downloader]   ↷ afec3b79-a9a8-456a-adfe-58ac22a4a7e2          already downloaded, skipping (resume=True)
#   2024-11-20: OK
# ⬇ 1 scene  →  data/obuasi_insar/raw/2024-12-02              0/1  [00:00]
# da2f383e-bb92-4640-8483-d9178da6de41: 0.00B [00:00, ?B/s]
# 17:34:30 INFO [  downloader]   ↷ da2f383e-bb92-4640-8483-d9178da6de41          already downloaded, skipping (resume=True)
#   2024-12-02: OK
# ⬇ 1 scene  →  data/obuasi_insar/raw/2024-12-14              0/1  [00:00]
# 7210e023-cbad-4a47-a6bc-9c122d34cc13: 0.00B [00:00, ?B/s]
# 17:34:45 INFO [  downloader]   ↷ 7210e023-cbad-4a47-a6bc-9c122d34cc13          already downloaded, skipping (resume=True)
#   2024-12-14: OK
# ⬇ 1 scene  →  data/obuasi_insar/raw/2024-12-26              0/1  [00:00]
# e9a3c871-6bb4-4a0b-aa4f-844da0aab8d5: 0.00B [00:00, ?B/s]
# 17:35:03 INFO [  downloader]   ↷ e9a3c871-6bb4-4a0b-aa4f-844da0aab8d5          already downloaded, skipping (resume=True)
#   2024-12-26: OK
# ⬇ 1 scene  →  data/obuasi_insar/raw/2025-01-07              0/1  [00:00]
# c6727038-f036-499c-a2ae-cf7911d7e121: 0.00B [00:00, ?B/s]
# 17:35:21 INFO [  downloader]   ↷ c6727038-f036-499c-a2ae-cf7911d7e121          already downloaded, skipping (resume=True)
#   2025-01-07: OK

# %% [markdown]
# ### 3b. Visualize a raw download — the SAFE product quicklook
#
# Every Sentinel-1 SAFE archive includes a real, standard quicklook
# preview image (ESA product specification — a `preview/` folder
# containing low-resolution PNG quicklooks), independent of any
# processing PyGeoFetch does. Extracting and showing it here confirms
# directly, before any real processing starts, that what actually
# downloaded is a real, sensible-looking SAR scene over the right area —
# not something to discover is wrong after 20 minutes of unwrapping.

# %%
import zipfile
import matplotlib.pyplot as plt
from PIL import Image
import io

def show_safe_quicklook(zip_path, title=""):
    with zipfile.ZipFile(zip_path) as zf:
        candidates = [n for n in zf.namelist() if "/preview/" in n and n.lower().endswith((".png", ".jpg", ".jpeg"))]
        if not candidates:
            print(f"  No preview quicklook found in {Path(zip_path).name} -- SAFE structure may differ from the documented spec, or the file may not have downloaded completely.")
            return None
        with zf.open(candidates[0]) as src:
            img = Image.open(io.BytesIO(src.read()))
    fig, ax = plt.subplots(figsize=(8, 6), facecolor="white")
    ax.imshow(img)
    ax.set_title(title)
    ax.axis("off")
    plt.tight_layout()
    plt.savefig(output_dir / "raw" / f"quicklook_{title.replace(' ', '_')}.png", dpi=100, facecolor="white", bbox_inches="tight")
    plt.show()
    return img

# Show the first and last downloaded dates -- enough to confirm the
# download is real and sensible without rendering every single one
sorted_download_labels = sorted(download_results.keys())
preview_labels = [sorted_download_labels[0], sorted_download_labels[-1]] if len(sorted_download_labels) >= 2 else sorted_download_labels
for label in preview_labels:
    show_safe_quicklook(download_results[label].output_path, title=f"Raw download — {label}")

# %% [markdown]
# ## 4. SLC extraction — the AOI-matching sub-swath from each scene
#
# Sentinel-1 IW SLC spans 3 sub-swaths per polarisation; the AOI
# typically falls in just one, and which one can vary per scene.
# `SLCExtractor` picks the correct sub-swath automatically via its
# embedded GCPs.

# %%
slc_extractor = SLCExtractor(polarisation="VV")
extracted_slcs = {}

from pygeofetch.models.search_query import BoundingBox

aoi_bbox = BoundingBox(
    min_lon=min(obuasi_lons), max_lon=max(obuasi_lons),
    min_lat=min(obuasi_lats), max_lat=max(obuasi_lats),
)

for label, result in download_results.items():
    slc_dir = output_dir / "slc" / label
    path = slc_extractor.extract_scene(result.output_path, aoi=aoi_bbox, output_dir=slc_dir, label=label)
    if path is not None:
        extracted_slcs[label] = path
        print(f"  {label}: extracted -> {path.name}")
    else:
        print(f"  {label}: no matching sub-swath found for this AOI")

if len(extracted_slcs) < 3:
    raise RuntimeError(f"Only {len(extracted_slcs)} SLC(s) extracted -- need at least 3.")
extracted_dates = sorted(extracted_slcs.keys())
print(f"\n{len(extracted_slcs)} SLCs extracted: {extracted_dates}")
# Out:
# 17:35:22 INFO [  extraction] Found 3 VV sub-swath(s) in S1A_IW_SLC__1SDV_20241108T182631_20241108T182700_056467_06EBBD_A753.SAFE.zip
# 17:35:24 INFO [  extraction] Cropped IW3: 23900x15040 -> 5804x1266 (48.9x smaller)
# 17:35:24 INFO [  extraction] Extracted IW3 -> 2024-11-08_vv.tif
#   2024-11-08: extracted -> 2024-11-08_vv.tif
# 17:35:24 INFO [  extraction] Found 3 VV sub-swath(s) in S1A_IW_SLC__1SDV_20241120T182630_20241120T182700_056642_06F2C7_9C51.SAFE.zip
# 17:35:25 INFO [  extraction] Cropped IW3: 23898x15040 -> 5804x1266 (48.9x smaller)
# 17:35:25 INFO [  extraction] Extracted IW3 -> 2024-11-20_vv.tif
#   2024-11-20: extracted -> 2024-11-20_vv.tif
# 17:35:25 INFO [  extraction] Found 3 VV sub-swath(s) in S1A_IW_SLC__1SDV_20241202T182629_20241202T182659_056817_06F9B6_84DA.SAFE.zip
# 17:35:27 INFO [  extraction] Cropped IW3: 23898x15040 -> 5804x1266 (48.9x smaller)
# 17:35:27 INFO [  extraction] Extracted IW3 -> 2024-12-02_vv.tif
#   2024-12-02: extracted -> 2024-12-02_vv.tif
# 17:35:27 INFO [  extraction] Found 3 VV sub-swath(s) in S1A_IW_SLC__1SDV_20241214T182628_20241214T182658_056992_070096_20FD.SAFE.zip
# 17:35:29 INFO [  extraction] Cropped IW3: 23901x15040 -> 5804x1266 (48.9x smaller)
# 17:35:29 INFO [  extraction] Extracted IW3 -> 2024-12-14_vv.tif
#   2024-12-14: extracted -> 2024-12-14_vv.tif
# 17:35:29 INFO [  extraction] Found 3 VV sub-swath(s) in S1A_IW_SLC__1SDV_20241226T182627_20241226T182657_057167_070794_94AB.SAFE.zip
# 17:35:31 INFO [  extraction] Cropped IW3: 23898x15040 -> 5803x1266 (48.9x smaller)
# 17:35:31 INFO [  extraction] Extracted IW3 -> 2024-12-26_vv.tif
#   2024-12-26: extracted -> 2024-12-26_vv.tif
# 17:35:31 INFO [  extraction] Found 3 VV sub-swath(s) in S1A_IW_SLC__1SDV_20250107T182626_20250107T182656_057342_070E79_2432.SAFE.zip
# 17:35:32 INFO [  extraction] Cropped IW3: 23898x15040 -> 5804x1267 (48.9x smaller)
# 17:35:32 INFO [  extraction] Extracted IW3 -> 2025-01-07_vv.tif
#   2025-01-07: extracted -> 2025-01-07_vv.tif
#
# 6 SLCs extracted: ['2024-11-08', '2024-11-20', '2024-12-02', '2024-12-14', '2024-12-26', '2025-01-07']

# %% [markdown]
# ### 4b. Visualize an extracted SLC — real amplitude, real speckle
#
# This is the actual complex data the interferogram chain will operate
# on — not a preview, the real extracted sub-swath. Real SAR amplitude
# always shows speckle (the grainy salt-and-pepper texture inherent to
# coherent radar imaging, discussed in the ESA InSAR manual, Part A
# §1.2.2.3) — a genuinely flat or overly smooth-looking result here
# would be the first sign something upstream went wrong, well before
# committing to the full interferogram/unwrapping/SBAS chain.

# %%
import rasterio

first_date = extracted_dates[0]
with rasterio.open(extracted_slcs[first_date]) as src:
    slc_sample = src.read(1)

amplitude_db = 20 * np.log10(np.abs(slc_sample) + 1e-10)
pl.plot_raster(
    amplitude_db, title=f"Extracted SLC Amplitude — {first_date}",
    colormap="gray", colorbar_label="Amplitude (dB)",
    # output=str(output_dir / "slc" / f"{first_date}_amplitude.png"),
)
print(f"Amplitude range: [{np.percentile(amplitude_db, 2):.1f}, {np.percentile(amplitude_db, 98):.1f}] dB (2nd-98th percentile)")
# Out:
# Amplitude range: [0.0, 47.5] dB (2nd-98th percentile)

# %%
right_edge = amplitude_db[:, -50:]
frac_invalid = (right_edge <= -199).mean()
print(f"Fraction of the rightmost 50 columns that are exactly -200dB: {frac_invalid:.2%}")

full_image_invalid = (amplitude_db <= -199).mean()
print(f"Fraction of the entire image that's exactly -200dB: {full_image_invalid:.2%}")
# Out:
# Fraction of the rightmost 50 columns that are exactly -200dB: 90.90%
# Fraction of the entire image that's exactly -200dB: 1.58%

# %%
import matplotlib.pyplot as plt

invalid_mask = amplitude_db <= -199
plt.figure(figsize=(10, 8))
plt.imshow(invalid_mask, cmap="Reds", interpolation="none")
plt.title("Exactly -200dB pixels (invalid/zero-return)")
plt.show()

print(f"Invalid pixels touching the burst boundary row range (550-600): "
      f"{invalid_mask[550:600, :-50].mean():.2%}")
print(f"Invalid pixels elsewhere (excluding burst band and right edge): "
      f"{invalid_mask[np.r_[0:550, 600:1266], :-50].mean():.2%}")
# Out:
# Invalid pixels touching the burst boundary row range (550-600): 3.00%
# Invalid pixels elsewhere (excluding burst band and right edge): 0.71%

# %% [markdown]
# ## 4c. Get a real DEM — needed for topographic phase removal and real coregistration
#
# Both the topographic phase removal in Section 5 and the real orbit-
# based coregistration added below need an actual DEM, not `None`.

# %%
# Get a real DEM for the AOI, replacing dem_path = None -- needed for
# topographic phase removal and atmospheric correction, both of which
# were silently skipped without one.
from pygeofetch.models.search_query import SearchQuery, BoundingBox
from pygeofetch.processing.preprocessor import Preprocessor

OPENTOPOGRAPHY_API_KEY = "b0d75bfc54e0d7e7d398381bbe3c5e94"
client.add_credentials("opentopography", api_key=OPENTOPOGRAPHY_API_KEY)

# opentopography's real API is bbox-only (not polygon), confirmed
# against its actual implementation earlier in this project

dem_aoi_bbox = BoundingBox(
    min_lon=min(obuasi_lons), max_lon=max(obuasi_lons),
    min_lat=min(obuasi_lats), max_lat=max(obuasi_lats),
)


dem_query = SearchQuery(bbox=dem_aoi_bbox, max_results=10)
dem_results = client.search(dem_query, providers=["opentopography"])

cop30_result = next((r for r in dem_results if r.properties.get("product") == "cop30"), None)
if cop30_result is None:
    raise RuntimeError("Copernicus DEM (30m) not found in search results -- cannot proceed without a real DEM.")
# Out:
# 17:35:35 INFO [authenticator] Credentials saved for provider 'opentopography'
# ┌ SEARCH PARAMETERS ───────────────────────────────────────────────────────┐
# │ Providers  : opentopography                                              │
# │ BBox       : [-1.753, 6.153, -1.633, 6.241]                              │
# │ Date range : None  →  None                                               │
# │ Cloud max  : 100%                                                        │
# │ Product    : any                                                         │
# └──────────────────────────────────────────────────────────────────────────┘
#   ✓  opentopography                   7 scenes   0.0s
# ┌────────────────────────────────────────────┬────────────┬────────────────┬────────┬─────────┬──────────────┬─────────────┬───────┬───────┬──────────────────────┐
# │                  SCENE ID                  │    DATE    │   SATELLITE    │ CLOUD  │ PRODUCT │ POLARISATION │    PASS     │ ORBIT │ SCORE │       PROVIDER       │
# ├────────────────────────────────────────────┼────────────┼────────────────┼────────┼─────────┼──────────────┼─────────────┼───────┼───────┼──────────────────────┤
# │ opentopo_SRTMGL3_-1.7531_6.1531            │ —          │ SRTM/Copernic… │ —      │ —       │ —            │ —           │ —     │ 0.50  │ opentopography       │
# │ opentopo_SRTMGL1_-1.7531_6.1531            │ —          │ SRTM/Copernic… │ —      │ —       │ —            │ —           │ —     │ 0.50  │ opentopography       │
# │ opentopo_COP30_-1.7531_6.1531              │ —          │ SRTM/Copernic… │ —      │ —       │ —            │ —           │ —     │ 0.50  │ opentopography       │
# │ opentopo_COP90_-1.7531_6.1531              │ —          │ SRTM/Copernic… │ —      │ —       │ —            │ —           │ —     │ 0.50  │ opentopography       │
# │ opentopo_NASADEM_-1.7531_6.1531            │ —          │ SRTM/Copernic… │ —      │ —       │ —            │ —           │ —     │ 0.50  │ opentopography       │
# │ opentopo_AW3D30_-1.7531_6.1531             │ —          │ SRTM/Copernic… │ —      │ —       │ —            │ —           │ —     │ 0.50  │ opentopography       │
# │ opentopo_GEDTM30_-1.7531_6.1531            │ —          │ SRTM/Copernic… │ —      │ —       │ —            │ —           │ —     │ 0.50  │ opentopography       │
# └────────────────────────────────────────────┴────────────┴────────────────┴────────┴─────────┴──────────────┴─────────────┴───────┴───────┴──────────────────────┘
#   7 scenes found  ·  0.0s

# %%
dem_download_dir = output_dir / "dem"
dem_dl_result = client.download([cop30_result], destination=dem_download_dir,
                                 options=DownloadOptions(parallel=1, resume=True, on_failure="skip"))[0]
if not dem_dl_result.success:
    raise RuntimeError(f"DEM download failed: {dem_dl_result.error}")
# Out:
# ⬇ 1 scene  →  data/obuasi_insar/dem              0/1  [00:00]
# opentopo_COP30_-1.7531_6.1531: 0.00B [00:00, ?B/s]
# 17:35:35 INFO [  downloader]   ↷ opentopo_COP30_-1.7531_6.1531                 already downloaded, skipping (resume=True)

# %%
# Clip to the real Obuasi boundary -- same clip-first pattern used
# throughout this project, not the full downloaded tile
pp_dem = Preprocessor()
dem_clip_result = pp_dem.clip(dem_dl_result.output_path, geometry=obuasi_geometry,
                               output=str(dem_download_dir / "obuasi_dem_clipped.tif"))
if not dem_clip_result.success:
    raise RuntimeError(f"DEM clip failed: {dem_clip_result.error}")

dem_path = dem_clip_result.output_path
print(f"Real DEM ready: {dem_path}")
# Out:
# 17:35:35 INFO [preprocessor] Clipped → data/obuasi_insar/dem/obuasi_dem_clipped.tif
# Real DEM ready: data/obuasi_insar/dem/obuasi_dem_clipped.tif

# %%
pl.plot_raster(
    dem_path, title=f"Real DEM — {first_date}",
    colormap="viridis",
    # output=str(output_dir / "slc" / f"{first_date}_amplitude.png"),
)
pl._save_or_show(fig=None,output='' )

# %% [markdown]
# ## 4d. Fetch real orbit files — for real orbit-based coregistration
#
# Real `.EOF` precise orbit files, one per acquisition date. Precise
# orbits typically aren't available until ~21 days after acquisition —
# if one isn't available yet for a given date, that specific pair falls
# back to shape-based coregistration automatically (via
# `process_pair()`'s existing graceful degradation), not a hard failure.

# %%
from pygeofetch.core.orbits import fetch_orbit_file

orbit_files = {}
orbit_dir = output_dir / "orbits"
for label, scene in scenes.items():
    product_name = scene.properties.get("name", scene.id)
    path = fetch_orbit_file(product_name=product_name, output_dir=str(orbit_dir), orbit_type="precise")
    if path is None:
        print(f"  {label}: no precise orbit file available yet (pair(s) using this date will")
        print(f"           fall back to shape-based coregistration automatically)")
    else:
        orbit_files[label] = path
        print(f"  {label}: {Path(path).name}")

print(f"\n{len(orbit_files)}/{len(scenes)} real orbit files available")
# Out:
# 17:35:36 INFO [      orbits] Using cached orbit file: S1A_OPER_AUX_POEORB_OPOD_20241128T070628_V20241107T225942_20241109T005942.EOF
#   2024-11-08: S1A_OPER_AUX_POEORB_OPOD_20241128T070628_V20241107T225942_20241109T005942.EOF
# 17:35:36 INFO [      orbits] Using cached orbit file: S1A_OPER_AUX_POEORB_OPOD_20241210T070622_V20241119T225942_20241121T005942.EOF
#   2024-11-20: S1A_OPER_AUX_POEORB_OPOD_20241210T070622_V20241119T225942_20241121T005942.EOF
# 17:35:36 INFO [      orbits] Using cached orbit file: S1A_OPER_AUX_POEORB_OPOD_20241222T070555_V20241201T225942_20241203T005942.EOF
#   2024-12-02: S1A_OPER_AUX_POEORB_OPOD_20241222T070555_V20241201T225942_20241203T005942.EOF
# 17:35:36 INFO [      orbits] Using cached orbit file: S1A_OPER_AUX_POEORB_OPOD_20250103T070550_V20241213T225942_20241215T005942.EOF
#   2024-12-14: S1A_OPER_AUX_POEORB_OPOD_20250103T070550_V20241213T225942_20241215T005942.EOF
# 17:35:36 INFO [      orbits] Using cached orbit file: S1A_OPER_AUX_POEORB_OPOD_20250115T070608_V20241225T225942_20241227T005942.EOF
#   2024-12-26: S1A_OPER_AUX_POEORB_OPOD_20250115T070608_V20241225T225942_20241227T005942.EOF
# 17:35:36 INFO [      orbits] Using cached orbit file: S1A_OPER_AUX_POEORB_OPOD_20250127T070616_V20250106T225942_20250108T005942.EOF
#   2025-01-07: S1A_OPER_AUX_POEORB_OPOD_20250127T070616_V20250106T225942_20250108T005942.EOF
#
# 6/6 real orbit files available

# %% [markdown]
# ## 5. Interferogram formation — short-baseline consecutive pairs
#
# A simple connected chain (each date paired with the next) — the
# minimal viable SBAS network design, guaranteed fully connected by
# construction. `DataValidator` runs automatically at the start of every
# `process_pair()` call (input SLC sanity checks) and after coherence
# estimation — real protection, not just available-but-unused code.
# `auto_visualize=True` saves wrapped phase, coherence, and amplitude
# PNGs for every pair without a separate plotting step.

# %%
ifg_gen = InterferogramGenerator(coherence_window=5, esd_enabled=True, use_gpu=False)
interferograms = {}

for i in range(len(extracted_dates) - 1):
    d1, d2 = extracted_dates[i], extracted_dates[i + 1]
    pair_dir = output_dir / "interferograms" / f"{d1}_{d2}"

    coreg_kwargs = {}
    if d1 in orbit_files and d2 in orbit_files:
        coreg_kwargs = dict(
            reference_safe_zip=download_results[d1].output_path,
            secondary_safe_zip=download_results[d2].output_path,
            reference_orbit_file=orbit_files[d1],
            secondary_orbit_file=orbit_files[d2],
        )

    try:
        result = ifg_gen.process_pair(
            reference=extracted_slcs[d1], secondary=extracted_slcs[d2],
            dem=dem_path, reference_date=d1, secondary_date=d2,
            **coreg_kwargs,
        )
    except ValueError as exc:
        print(f"  {d1} -> {d2}: REJECTED by DataValidator -- {exc}")
        continue

    result.save(pair_dir, auto_visualize=True)
    interferograms[(d1, d2)] = result
    print(f"  {d1} -> {d2}: OK, mean coherence {np.mean(result.coherence):.3f}")

if len(interferograms) < 2:
    raise RuntimeError(f"Only {len(interferograms)} interferogram(s) formed -- need at least 2 for SBAS.")
# Out:
# 17:35:37 INFO [  annotation] Parsed real SLC geometry from S1A_IW_SLC__1SDV_20241108T182631_20241108T182700_056467_06EBBD_A753.SAFE.zip: 15040 x 23900, starting 2024-11-08 18:26:33.036442
# 17:35:37 INFO [  annotation] Parsed real SLC geometry from S1A_IW_SLC__1SDV_20241120T182630_20241120T182700_056642_06F2C7_9C51.SAFE.zip: 15040 x 23898, starting 2024-11-20 18:26:32.468821
# 17:35:37 INFO [ geolocation] Parsed 9361 orbit state vectors from S1A_OPER_AUX_POEORB_OPOD_20241128T070628_V20241107T225942_20241109T005942.EOF
# 17:35:37 INFO [ geolocation] Parsed 9361 orbit state vectors from S1A_OPER_AUX_POEORB_OPOD_20241210T070622_V20241119T225942_20241121T005942.EOF
# 17:35:38 INFO [  coregister] DEM-driven offset field: 49/49 points solved successfully
# 17:35:38 INFO [interferogram] Correcting for cropped extraction: reference offset (11477, 18047), secondary offset (11474, 18059)
# 17:35:38 INFO [interferogram] Real orbit-based coregistration applied (49 grid points)
# 17:35:40 INFO [interferogram] ESD azimuth shift applied: -0.00071 px
# 17:35:43 INFO [interferogram] DEM-elevation correlation too weak (R²=0.00) — skipping topographic phase removal to avoid absorbing real signal. This is expected when little/no residual topographic phase is present (e.g. accurate DEM, small baseline).
# 17:35:43 INFO [interferogram] DEM supplied (obuasi_dem_clipped.tif) but topographic phase was NOT removed — see the reason logged above (R² gate, insufficient valid pixels, or an error). The interferogram was still produced.
# 17:35:45 INFO [interferogram] Interferogram products saved → data/obuasi_insar/interferograms/2024-11-08_2024-11-20
# 17:35:46 INFO [        plot] Plot saved → data/obuasi_insar/interferograms/2024-11-08_2024-11-20/wrapped_phase.png
# 17:35:48 INFO [        plot] Plot saved → data/obuasi_insar/interferograms/2024-11-08_2024-11-20/coherence.png
# 17:35:49 INFO [        plot] Plot saved → data/obuasi_insar/interferograms/2024-11-08_2024-11-20/amplitude.png
# 17:35:49 INFO [   visualize] Interferogram visualizations saved → data/obuasi_insar/interferograms/2024-11-08_2024-11-20
#   2024-11-08 -> 2024-11-20: OK, mean coherence 0.282
# 17:35:49 INFO [  annotation] Parsed real SLC geometry from S1A_IW_SLC__1SDV_20241120T182630_20241120T182700_056642_06F2C7_9C51.SAFE.zip: 15040 x 23898, starting 2024-11-20 18:26:32.468821
# 17:35:49 INFO [  annotation] Parsed real SLC geometry from S1A_IW_SLC__1SDV_20241202T182629_20241202T182659_056817_06F9B6_84DA.SAFE.zip: 15040 x 23898, starting 2024-12-02 18:26:31.773888
# 17:35:49 INFO [ geolocation] Parsed 9361 orbit state vectors from S1A_OPER_AUX_POEORB_OPOD_20241210T070622_V20241119T225942_20241121T005942.EOF
# 17:35:50 INFO [ geolocation] Parsed 9361 orbit state vectors from S1A_OPER_AUX_POEORB_OPOD_20241222T070555_V20241201T225942_20241203T005942.EOF
# 17:35:51 INFO [  coregister] DEM-driven offset field: 49/49 points solved successfully
# 17:35:51 INFO [interferogram] Correcting for cropped extraction: reference offset (11474, 18059), secondary offset (11476, 18062)
# 17:35:51 INFO [interferogram] Real orbit-based coregistration applied (49 grid points)
# 17:35:52 INFO [interferogram] ESD azimuth shift applied: -0.00068 px
# 17:35:55 INFO [interferogram] DEM-elevation correlation too weak (R²=-0.00) — skipping topographic phase removal to avoid absorbing real signal. This is expected when little/no residual topographic phase is present (e.g. accurate DEM, small baseline).
# 17:35:55 INFO [interferogram] DEM supplied (obuasi_dem_clipped.tif) but topographic phase was NOT removed — see the reason logged above (R² gate, insufficient valid pixels, or an error). The interferogram was still produced.
# 17:35:57 INFO [interferogram] Interferogram products saved → data/obuasi_insar/interferograms/2024-11-20_2024-12-02
# 17:35:58 INFO [        plot] Plot saved → data/obuasi_insar/interferograms/2024-11-20_2024-12-02/wrapped_phase.png
# 17:35:59 INFO [        plot] Plot saved → data/obuasi_insar/interferograms/2024-11-20_2024-12-02/coherence.png
# 17:36:00 INFO [        plot] Plot saved → data/obuasi_insar/interferograms/2024-11-20_2024-12-02/amplitude.png
# 17:36:00 INFO [   visualize] Interferogram visualizations saved → data/obuasi_insar/interferograms/2024-11-20_2024-12-02
#   2024-11-20 -> 2024-12-02: OK, mean coherence 0.283
# 17:36:01 INFO [  annotation] Parsed real SLC geometry from S1A_IW_SLC__1SDV_20241202T182629_20241202T182659_056817_06F9B6_84DA.SAFE.zip: 15040 x 23898, starting 2024-12-02 18:26:31.773888
# 17:36:01 INFO [  annotation] Parsed real SLC geometry from S1A_IW_SLC__1SDV_20241214T182628_20241214T182658_056992_070096_20FD.SAFE.zip: 15040 x 23901, starting 2024-12-14 18:26:30.834739
# 17:36:01 INFO [ geolocation] Parsed 9361 orbit state vectors from S1A_OPER_AUX_POEORB_OPOD_20241222T070555_V20241201T225942_20241203T005942.EOF
# 17:36:01 INFO [ geolocation] Parsed 9361 orbit state vectors from S1A_OPER_AUX_POEORB_OPOD_20250103T070550_V20241213T225942_20241215T005942.EOF
# 17:36:02 INFO [  coregister] DEM-driven offset field: 49/49 points solved successfully
# 17:36:02 INFO [interferogram] Correcting for cropped extraction: reference offset (11476, 18062), secondary offset (11477, 18073)
# 17:36:02 INFO [interferogram] Real orbit-based coregistration applied (49 grid points)
# 17:36:03 INFO [interferogram] ESD azimuth shift applied: -0.00343 px
# 17:36:06 INFO [interferogram] DEM-elevation correlation too weak (R²=-0.00) — skipping topographic phase removal to avoid absorbing real signal. This is expected when little/no residual topographic phase is present (e.g. accurate DEM, small baseline).
# 17:36:06 INFO [interferogram] DEM supplied (obuasi_dem_clipped.tif) but topographic phase was NOT removed — see the reason logged above (R² gate, insufficient valid pixels, or an error). The interferogram was still produced.
# 17:36:08 INFO [interferogram] Interferogram products saved → data/obuasi_insar/interferograms/2024-12-02_2024-12-14
# 17:36:09 INFO [        plot] Plot saved → data/obuasi_insar/interferograms/2024-12-02_2024-12-14/wrapped_phase.png
# 17:36:10 INFO [        plot] Plot saved → data/obuasi_insar/interferograms/2024-12-02_2024-12-14/coherence.png
# 17:36:12 INFO [        plot] Plot saved → data/obuasi_insar/interferograms/2024-12-02_2024-12-14/amplitude.png
# 17:36:12 INFO [   visualize] Interferogram visualizations saved → data/obuasi_insar/interferograms/2024-12-02_2024-12-14
#   2024-12-02 -> 2024-12-14: OK, mean coherence 0.271
# 17:36:12 INFO [  annotation] Parsed real SLC geometry from S1A_IW_SLC__1SDV_20241214T182628_20241214T182658_056992_070096_20FD.SAFE.zip: 15040 x 23901, starting 2024-12-14 18:26:30.834739
# 17:36:12 INFO [  annotation] Parsed real SLC geometry from S1A_IW_SLC__1SDV_20241226T182627_20241226T182657_057167_070794_94AB.SAFE.zip: 15040 x 23898, starting 2024-12-26 18:26:29.569052
# 17:36:12 INFO [ geolocation] Parsed 9361 orbit state vectors from S1A_OPER_AUX_POEORB_OPOD_20250103T070550_V20241213T225942_20241215T005942.EOF
# 17:36:13 INFO [ geolocation] Parsed 9361 orbit state vectors from S1A_OPER_AUX_POEORB_OPOD_20250115T070608_V20241225T225942_20241227T005942.EOF
# 17:36:13 INFO [  coregister] DEM-driven offset field: 49/49 points solved successfully
# 17:36:13 INFO [interferogram] Correcting for cropped extraction: reference offset (11477, 18073), secondary offset (11480, 18044)
# 17:36:13 INFO [interferogram] Real orbit-based coregistration applied (49 grid points)
# 17:36:15 INFO [interferogram] ESD azimuth shift applied: -0.00443 px
# 17:36:17 INFO [interferogram] DEM-elevation correlation too weak (R²=0.00) — skipping topographic phase removal to avoid absorbing real signal. This is expected when little/no residual topographic phase is present (e.g. accurate DEM, small baseline).
# 17:36:17 INFO [interferogram] DEM supplied (obuasi_dem_clipped.tif) but topographic phase was NOT removed — see the reason logged above (R² gate, insufficient valid pixels, or an error). The interferogram was still produced.
# 17:36:19 INFO [interferogram] Interferogram products saved → data/obuasi_insar/interferograms/2024-12-14_2024-12-26
# 17:36:20 INFO [        plot] Plot saved → data/obuasi_insar/interferograms/2024-12-14_2024-12-26/wrapped_phase.png
# 17:36:22 INFO [        plot] Plot saved → data/obuasi_insar/interferograms/2024-12-14_2024-12-26/coherence.png
# 17:36:23 INFO [        plot] Plot saved → data/obuasi_insar/interferograms/2024-12-14_2024-12-26/amplitude.png
# 17:36:23 INFO [   visualize] Interferogram visualizations saved → data/obuasi_insar/interferograms/2024-12-14_2024-12-26
#   2024-12-14 -> 2024-12-26: OK, mean coherence 0.278
# 17:36:23 INFO [  annotation] Parsed real SLC geometry from S1A_IW_SLC__1SDV_20241226T182627_20241226T182657_057167_070794_94AB.SAFE.zip: 15040 x 23898, starting 2024-12-26 18:26:29.569052
# 17:36:23 INFO [  annotation] Parsed real SLC geometry from S1A_IW_SLC__1SDV_20250107T182626_20250107T182656_057342_070E79_2432.SAFE.zip: 15040 x 23898, starting 2025-01-07 18:26:28.475957
# 17:36:23 INFO [ geolocation] Parsed 9361 orbit state vectors from S1A_OPER_AUX_POEORB_OPOD_20250115T070608_V20241225T225942_20241227T005942.EOF
# 17:36:24 INFO [ geolocation] Parsed 9361 orbit state vectors from S1A_OPER_AUX_POEORB_OPOD_20250127T070616_V20250106T225942_20250108T005942.EOF
# 17:36:25 INFO [  coregister] DEM-driven offset field: 49/49 points solved successfully
# 17:36:25 INFO [interferogram] Correcting for cropped extraction: reference offset (11480, 18044), secondary offset (11477, 18048)
# 17:36:25 INFO [interferogram] Real orbit-based coregistration applied (49 grid points)
# 17:36:26 INFO [interferogram] ESD azimuth shift applied: -0.00178 px
# 17:36:29 INFO [interferogram] DEM-elevation correlation too weak (R²=0.00) — skipping topographic phase removal to avoid absorbing real signal. This is expected when little/no residual topographic phase is present (e.g. accurate DEM, small baseline).
# 17:36:29 INFO [interferogram] DEM supplied (obuasi_dem_clipped.tif) but topographic phase was NOT removed — see the reason logged above (R² gate, insufficient valid pixels, or an error). The interferogram was still produced.
# 17:36:31 INFO [interferogram] Interferogram products saved → data/obuasi_insar/interferograms/2024-12-26_2025-01-07
# 17:36:32 INFO [        plot] Plot saved → data/obuasi_insar/interferograms/2024-12-26_2025-01-07/wrapped_phase.png
# 17:36:33 INFO [        plot] Plot saved → data/obuasi_insar/interferograms/2024-12-26_2025-01-07/coherence.png
# 17:36:34 INFO [        plot] Plot saved → data/obuasi_insar/interferograms/2024-12-26_2025-01-07/amplitude.png
# 17:36:34 INFO [   visualize] Interferogram visualizations saved → data/obuasi_insar/interferograms/2024-12-26_2025-01-07
#   2024-12-26 -> 2025-01-07: OK, mean coherence 0.279

# %% [markdown]
# ## 6. Atmospheric correction — elevation-correlated method
#
# The elevation-correlated method needs no external data download (unlike
# ERA5), making it the more robust default for a reusable template.
# Applied to each interferogram's phase before unwrapping.

# %%
atm_corrector = AtmosphericCorrector(method="elevation")
corrected_interferograms = {}
atm_metadata = {}

if dem_path is not None:
    for (d1, d2), result in interferograms.items():
        wrapped_phase = np.angle(result.interferogram)
        corrected_phase, atm_meta = atm_corrector.correct(
            wrapped_phase, dem=dem_path, return_metadata=True
        )
        corrected_interferograms[(d1, d2)] = corrected_phase
        atm_metadata[(d1, d2)] = atm_meta

        r2 = atm_meta.get("r_squared")
        if atm_meta["correction_applied"]:
            print(f"  {d1} -> {d2}: atmospheric correction applied (R²={r2:.2f})")
        else:
            print(f"  {d1} -> {d2}: atmospheric correction skipped (R² = {r2!r}, too weak to trust)")
else:
    print("No DEM supplied -- skipping atmospheric correction (needs a DEM for")
    print("elevation-correlation) and using raw wrapped phase directly for unwrapping.")
    print("Supply dem_path (e.g. from an earlier Preprocessor.clip() call) for a full run.")
    corrected_interferograms = {k: np.angle(v.interferogram) for k, v in interferograms.items()}
# Out:
# 17:42:51 INFO [  atmosphere] Elevation correlation too weak (R²=0.00) — skipping atmospheric correction to avoid absorbing real deformation signal.
#   2024-11-08 -> 2024-11-20: atmospheric correction skipped (R² = 6.920099258422852e-05, too weak to trust)
# 17:42:52 INFO [  atmosphere] Elevation correlation too weak (R²=0.00) — skipping atmospheric correction to avoid absorbing real deformation signal.
#   2024-11-20 -> 2024-12-02: atmospheric correction skipped (R² = 9.042024612426758e-05, too weak to trust)
# 17:42:52 INFO [  atmosphere] Elevation correlation too weak (R²=0.00) — skipping atmospheric correction to avoid absorbing real deformation signal.
#   2024-12-02 -> 2024-12-14: atmospheric correction skipped (R² = 7.390975952148438e-05, too weak to trust)
# 17:42:53 INFO [  atmosphere] Elevation correlation too weak (R²=0.00) — skipping atmospheric correction to avoid absorbing real deformation signal.
#   2024-12-14 -> 2024-12-26: atmospheric correction skipped (R² = 8.863210678100586e-05, too weak to trust)
# 17:42:53 INFO [  atmosphere] Elevation correlation too weak (R²=0.00) — skipping atmospheric correction to avoid absorbing real deformation signal.
#   2024-12-26 -> 2025-01-07: atmospheric correction skipped (R² = 5.632638931274414e-05, too weak to trust)

# %% [markdown]
# ### 6b. Before/after — what the atmospheric correction actually removed
#
# The third panel (the difference) is the real diagnostic here — it
# should look like the smooth, broad-scale spatial pattern atmospheric
# turbulence actually produces (ESA InSAR manual, Part A §2.4), not
# random noise or a pattern that follows the topography (which would
# suggest the correction is instead removing real deformation or
# residual terrain signal, not atmosphere).

# %%
if dem_path is not None and interferograms:
    first_pair = list(interferograms.keys())[0]
    phase_before = np.angle(interferograms[first_pair].interferogram)
    phase_after = corrected_interferograms[first_pair]

    fig, axes = plt.subplots(1, 3, figsize=(16, 5), facecolor="white")
    for ax in axes:
        ax.set_facecolor("white")
    im0 = axes[0].imshow(phase_before, cmap="twilight", vmin=-np.pi, vmax=np.pi)
    axes[0].set_title("Before correction")
    plt.colorbar(im0, ax=axes[0], fraction=0.046)
    im1 = axes[1].imshow(phase_after, cmap="twilight", vmin=-np.pi, vmax=np.pi)
    axes[1].set_title("After correction")
    plt.colorbar(im1, ax=axes[1], fraction=0.046)
    im2 = axes[2].imshow(phase_before - phase_after, cmap="RdBu")
    axes[2].set_title("Removed (atmospheric contribution)")
    plt.colorbar(im2, ax=axes[2], fraction=0.046)
    fig.suptitle(f"Atmospheric Correction — {first_pair[0]} to {first_pair[1]}")
    plt.tight_layout()
    plt.savefig(output_dir / "atmosphere_before_after.png", dpi=120, facecolor="white", bbox_inches="tight")
    plt.show()
else:
    print("No DEM supplied this run -- atmospheric correction was skipped in Section 6,")
    print("so there's nothing to compare before/after here. Supply dem_path for this view.")

# %% [markdown]
# ## 7. Phase unwrapping — SNAPHU
#
# Pure-Python via `snaphu-py` — no separate system-level SNAPHU install
# needed. `visualize_unwrapped()` saves the unwrapped phase, connected-
# component mask, and reference coherence for every pair automatically.

# %%
unwrapper = PhaseUnwrapper(cost_mode="defo", init_method="mcf")
unwrapped_results = {}

for (d1, d2), phase in corrected_interferograms.items():
    coherence = interferograms[(d1, d2)].coherence
    unwrapped, conncomp = unwrapper.unwrap(phase, coherence)
    unwrapped_results[(d1, d2)] = unwrapped

    unwrap_dir = output_dir / "unwrapped" / f"{d1}_{d2}"
    visualize_unwrapped(unwrapped, conncomp, unwrap_dir, coherence=coherence)
    print(f"  {d1} -> {d2}: unwrapped, range [{np.nanmin(unwrapped):.2f}, {np.nanmax(unwrapped):.2f}] rad")
# Out:
# 20:25:16 INFO [      unwrap] Unwrapping 1266x5804 pixels (cost=defo, init=mcf, nlooks=1.0)
#
# snaphu v2.0.7
# 22 parameters input from file /tmp/tmpg2mvuf60/snaphu.config.dduwnb0z.txt (22 lines total)
# Reading wrapped phase from file /tmp/tmpg2mvuf60/snaphu.igram.n8xgx1vl.c8
# No weight file specified.  Assuming uniform weights
# Reading correlation data from file /tmp/tmpg2mvuf60/snaphu.corr.iv60jalb.f4
# Calculating deformation-mode cost parameters
# Initializing flows with MCF algorithm
# Running nonlinear network flow optimizer
# Maximum flow on network: 2
# Flow increment: 1  (Total improvements: 0)
# Found 1 valid set(s) of connected nodes
# Growing connected component mask
# Writing connected components to file /tmp/tmpg2mvuf60/snaphu.conncomp.g50otq4m.u4 as 4-byte unsigned ints
# Maximum flow on network: 1
# Total solution cost: 96937070
# Integrating phase
# Writing output to file /tmp/tmpg2mvuf60/snaphu.unw.1k5f1_u5.f4
# Program snaphu done
# Elapsed processor time:   0:17:46.26
# Elapsed wall clock time:  0:17:50
# 20:43:06 WARN [      unwrap] 100.0% of pixels are in the unreliable connected component (conncomp==0). Consider improving coherence via multilooking or filtering, or check for large decorrelated areas.
# 20:43:07 INFO [        plot] Plot saved → data/obuasi_insar/unwrapped/2024-11-08_2024-11-20/unwrapped_phase.png
# 20:43:08 INFO [        plot] Plot saved → data/obuasi_insar/unwrapped/2024-11-08_2024-11-20/connected_components.png
# 20:43:09 INFO [        plot] Plot saved → data/obuasi_insar/unwrapped/2024-11-08_2024-11-20/coherence_reference.png
# 20:43:09 INFO [   visualize] Unwrapping visualizations saved → data/obuasi_insar/unwrapped/2024-11-08_2024-11-20
#   2024-11-08 -> 2024-11-20: unwrapped, range [-100.87, 72.73] rad
# 20:43:10 INFO [      unwrap] Unwrapping 1266x5804 pixels (cost=defo, init=mcf, nlooks=1.0)
#
# snaphu v2.0.7
# 22 parameters input from file /tmp/tmpskczdhva/snaphu.config.cdx4_mo3.txt (22 lines total)
# Reading wrapped phase from file /tmp/tmpskczdhva/snaphu.igram.y_5gkyo2.c8
# No weight file specified.  Assuming uniform weights
# Reading correlation data from file /tmp/tmpskczdhva/snaphu.corr.r9ffulkt.f4
# Calculating deformation-mode cost parameters
# Initializing flows with MCF algorithm
# Running nonlinear network flow optimizer
# Maximum flow on network: 3
# Flow increment: 1  (Total improvements: 0)
# Found 1 valid set(s) of connected nodes
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[39], line 6
#       2 unwrapped_results = {}
#       3
#       4 for (d1, d2), phase in corrected_interferograms.items():
#       5     coherence = interferograms[(d1, d2)].coherence
# ----> 6     unwrapped, conncomp = unwrapper.unwrap(phase, coherence)
#       7     unwrapped_results[(d1, d2)] = unwrapped
#       8
#       9     unwrap_dir = output_dir / "unwrapped" / f"{d1}_{d2}"
#
# File ~/PyGeoFetch-1.0 (2).0-complete/pygeofetch/pygeofetch/insar/unwrap.py:147, in PhaseUnwrapper.unwrap(self, interferogram, coherence, nlooks, mask)
#     138 logger.info(
#     139     "Unwrapping %s pixels (cost=%s, init=%s, nlooks=%.1f)",
#     140     f"{igram.shape[0]}x{igram.shape[1]}",
#    (...)    143     nlooks,
#     144 )
#     146 try:
# --> 147     unwrapped, conncomp = sx.unwrap(
#     148         igram,
#     149         corr,
#     150         nlooks=nlooks,
#     151         cost=self._cost_mode,
#     152         init=self._init_method,
#     153     )
#     154 except Exception as exc:
#     155     raise RuntimeError(
#     156         f"SNAPHU unwrapping failed: {exc}\n"
#     157         "Common causes: incompatible array shapes, all-zero coherence, "
#     158         "or insufficient memory for large scenes. Consider multilooking "
#     159         "the interferogram first to reduce pixel count."
#     160     ) from exc
#
# File ~/PyGeoFetch-1.0 (2).0-complete/pygeofetch/venv/lib/python3.12/site-packages/snaphu/_unwrap.py:401, in unwrap(igram, corr, nlooks, cost, init, mask, min_conncomp_frac, phase_grad_window, ntiles, tile_overlap, nproc, tile_cost_thresh, min_region_size, single_tile_reoptimize, regrow_conncomps, scratchdir, delete_scratch, unw, conncomp)
#     398 Path(config_file).write_text(config)
#     400 # Run SNAPHU with the specified parameters.
# --> 401 run_snaphu(config_file)
#     403 # Optionally regrow connected component labels from the unwrapped phase if
#     404 # SNAPHU was run in tiled mode. This step should have no effect if SNAPHU was
#     405 # previously run in single-tile mode or if single-tile re-optimization was
#     406 # enabled, so always skip it in such cases.
#     407 if (not single_tile) and (not single_tile_reoptimize) and regrow_conncomps:
#     408     # The connected component regrowing step takes as input the unwrapped phase,
#     409     # which is missing magnitude information. The magnitude may be necessary,
#     410     # for example, to detect zero-magnitude pixels which should be masked out
#     411     # (i.e. connected component label set to 0). So compute the interferogram
#     412     # magnitude and pass it as a separate input file.
#
# File ~/PyGeoFetch-1.0 (2).0-complete/pygeofetch/venv/lib/python3.12/site-packages/snaphu/_snaphu.py:89, in run_snaphu(config_file)
#      87 args = [os.fspath(snaphu), "-f", os.fspath(config_file)]
#      88 try:
# ---> 89     subprocess.run(args, stderr=subprocess.PIPE, check=True, text=True)
#      90 except subprocess.CalledProcessError as e:
#      91     errmsg = e.stderr.strip()
#
# File /usr/lib/python3.12/subprocess.py:550, in run(input, capture_output, timeout, check, *popenargs, **kwargs)
#     548 with Popen(*popenargs, **kwargs) as process:
#     549     try:
# --> 550         stdout, stderr = process.communicate(input, timeout=timeout)
#     551     except TimeoutExpired as exc:
#     552         process.kill()
#
# File /usr/lib/python3.12/subprocess.py:1199, in Popen.communicate(self, input, timeout)
#    1197     self.stdout.close()
#    1198 elif self.stderr:
# -> 1199     stderr = self.stderr.read()
#    1200     self.stderr.close()
#    1201 self.wait()
#
# File <frozen codecs>:319, in BufferedIncrementalDecoder.decode(self, input, final)
# --> 319 'Could not get source, probably due dynamically evaluated source code.'
#
# KeyboardInterrupt:

# %% [markdown]
# ## 8. SBAS network assembly and connectivity check
#
# The consecutive-pair chain built in Section 5 is fully connected by
# construction, but `DataValidator` checks this explicitly and directly
# here too (not just relying on the automatic check inside `invert()`),
# since a disconnected network is exactly the kind of design mistake
# worth catching visibly before the expensive inversion runs.

# %%
sbas_pairs = [
    InterferogramPair(
        reference_date=d1, secondary_date=d2,
        unwrapped_phase=unwrapped_results[(d1, d2)],
        coherence=interferograms[(d1, d2)].coherence,
    )
    for (d1, d2) in unwrapped_results.keys()
]

network_check = DataValidator.validate_sbas_network(sbas_pairs, extracted_dates)
print(f"SBAS network valid: {network_check.valid}")
if network_check.warnings:
    print(f"Warnings: {network_check.warnings}")
network_check.raise_if_invalid()
print(f"Network confirmed connected: {len(sbas_pairs)} interferograms across {len(extracted_dates)} dates")

# %% [markdown]
# ### 8b. SBAS network diagram — the actual baseline connectivity
#
# A direct visual of exactly which dates are connected to which — the
# real network `DataValidator` just confirmed connected in Section 8,
# shown rather than just asserted.

# %%
from datetime import date as _date

day_nums = [(_date.fromisoformat(d) - _date.fromisoformat(extracted_dates[0])).days for d in extracted_dates]
date_to_day = dict(zip(extracted_dates, day_nums))

fig, ax = plt.subplots(figsize=(11, 4), facecolor="white")
ax.set_facecolor("white")
for d1, d2 in unwrapped_results.keys():
    ax.plot([date_to_day[d1], date_to_day[d2]], [0, 0], "-", color="#969696", linewidth=1.5, zorder=0)
for d, day in date_to_day.items():
    ax.plot(day, 0, "o", color="#08519c", markersize=11, zorder=2)
    ax.annotate(d, (day, 0), textcoords="offset points", xytext=(0, 14), ha="center", fontsize=9, rotation=20)
ax.set_yticks([])
ax.set_xlabel("Days since first acquisition")
ax.set_title(f"SBAS Network — {len(unwrapped_results)} interferograms, {len(extracted_dates)} dates, fully connected")
plt.tight_layout()
plt.savefig(output_dir / "sbas_network_diagram.png", dpi=120, facecolor="white", bbox_inches="tight")
plt.show()

# %% [markdown]
# ## 9. SBAS inversion — displacement time series
#
# `use_gpu=False` set explicitly, matching this notebook's CPU-only
# framing throughout. `auto_visualize=True` saves the velocity map,
# residual RMS map, and a composite per-date displacement grid
# automatically.

# %%
sbas = SBASTimeSeries(reference_date=extracted_dates[0], use_gpu=False)
ts_result = sbas.invert(sbas_pairs, coherence_threshold=0.3)

ts_dir = output_dir / "timeseries"
ts_result.save(ts_dir, auto_visualize=True)

print(f"Time series inversion complete: {len(ts_result.dates)} dates")
print(f"Mean velocity: {np.nanmean(ts_result.velocity)*1000:.2f} mm/year")
print(f"Velocity range: [{np.nanmin(ts_result.velocity)*1000:.1f}, {np.nanmax(ts_result.velocity)*1000:.1f}] mm/year")
print(f"Mean inversion residual RMS: {np.nanmean(ts_result.residual_rms)*1000:.2f} mm")

# %% [markdown]
# ## 10. Subsidence hotspot identification
#
# Areas with a real, statistically meaningful downward (negative LOS
# velocity, moving away from the sensor) trend — the direct,
# InSAR-specific evidence the earlier optical vegetation-decline
# analysis of this same area could not provide on its own.

# %%
subsidence_threshold_mm_yr = -10.0  # meaningful negative LOS velocity
velocity_mm_yr = ts_result.velocity * 1000

subsiding_pct = 100 * np.nanmean(velocity_mm_yr < subsidence_threshold_mm_yr)
print(f"Area with LOS velocity < {subsidence_threshold_mm_yr} mm/year (likely real subsidence): {subsiding_pct:.1f}%")

pl.plot_raster(
    velocity_mm_yr,
    title=f"Obuasi — LOS Displacement Velocity ({subsiding_pct:.1f}% subsiding)",
    colormap="RdBu_r", vmin=-30, vmax=30,
    colorbar_label="LOS velocity (mm/year, negative = moving away from sensor)",
    output=str(output_dir / "subsidence_map.png"),
)

# %% [markdown]
# ## Summary
#
# **A complete, real InSAR chain, search to SBAS, entirely on CPU:**
#
# - Real Sentinel-1 SLC data (not GRD), across a real multi-baseline
#   network, not a single pair
# - Every processing step (`InterferogramGenerator`, `PhaseUnwrapper`,
#   `SBASTimeSeries`) protected by `DataValidator`, wired in and running
#   automatically, not just present-but-unused
# - Every step auto-visualized (`auto_visualize=True`) — wrapped phase,
#   coherence, amplitude, unwrapped phase, connected components,
#   velocity, residual RMS, and per-date displacement, all saved without
#   a separate manual plotting step
# - `use_gpu=False` set explicitly throughout — the CPU path, which is
#   the one directly, exhaustively verified this session
# - Connects to real optical evidence from the earlier Obuasi vegetation
#   notebook — a genuine multi-sensor picture of mining impact, not a
#   single-sensor claim
#
# ### Honest limitations
#
# - No DEM was supplied in this run by default — topographic phase was
#   not removed, and atmospheric correction was skipped. For a full,
#   publication-quality result, supply a real DEM (e.g. via
#   `Preprocessor.clip()` from the DEM notebooks earlier in this
#   series) as `dem_path` in Section 5.
# - The reference pixel for SBAS inversion was left at its automatic
#   default (highest mean coherence). For real subsidence monitoring,
#   explicitly choose a known-stable reference location (bedrock,
#   a building rooftop) well away from the expected deformation area.
# - This is LOS (line-of-sight) displacement, not vertical subsidence
#   directly — converting requires knowledge of the deformation's true
#   3D direction, which for mining subsidence is usually a reasonable
#   assumption (dominantly vertical) but not automatically true.
#
# ### References
#
# - Berardino, P. et al. (2002). SBAS inversion methodology.
# - Chen, C.W. & Zebker, H.A. (2001). SNAPHU phase unwrapping.
# - `15_obuasi_vegetation_timeseries_trend.ipynb` — the optical
#   companion analysis for this same site.
